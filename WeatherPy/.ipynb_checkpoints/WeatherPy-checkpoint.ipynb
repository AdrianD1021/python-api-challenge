# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import citipy
import scipy
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []
latlngs=[]

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    #latlngs = (lat_lng[0],lat_lng[1])
    
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        latlngs.append(lat_lng[0] + lat_lng[1])
        

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 610

# %% [markdown]
# ---

# %%
#print(cities)
#print(latlngs)

# %%
#url='http://www.api.openweathermap.org/data/2.5/weather?'
#city_url=f'{url}appid={weather_api_key}&q={city}&units{units}'
#weather_reply=requests.get(city_url)
#city_weather=weather_reply.json()

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
#url=f"http://www.api.openweathermap.org/data/2.5/weather?&appid={weather_api_key}&units=metric"
#units='imperial'
#url= 'http://api.openweathermap.org/geo/1.0/direct?q='
url='https://api.openweathermap.org/data/2.5/weather?q='
print(url)

# Define an empty list to fetch the weather data for each city
city_data = []

#Defining units for search
#units='metric'

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    #city_url = f'{url}{city}&limit=5&appid{weather_api_key}'
    city_url=f'{url}{city}&appid={weather_api_key}'
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = round(city_weather['main']['temp_max']-273.15)
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        #city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
        city_date=city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
        #print(city_url)

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        #print(city_url)
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# https://api.openweathermap.org/data/2.5/weather?q=
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | nagqu
# Processing Record 2 of Set 1 | college
# Processing Record 3 of Set 1 | mizdah
# Processing Record 4 of Set 1 | ust-nera
# Processing Record 5 of Set 1 | bilibino
# Processing Record 6 of Set 1 | isafjordur
# Processing Record 7 of Set 1 | chiili
# City not found. Skipping...
# Processing Record 8 of Set 1 | san antonio de pale
# Processing Record 9 of Set 1 | kailua-kona
# Processing Record 10 of Set 1 | grytviken
# Processing Record 11 of Set 1 | wamba
# Processing Record 12 of Set 1 | blackmans bay
# Processing Record 13 of Set 1 | kilindoni
# Processing Record 14 of Set 1 | iqaluit
# Processing Record 15 of Set 1 | port-aux-francais
# Processing Record 16 of Set 1 | nikolayevsk-on-amure
# Processing Record 17 of Set 1 | yaren
# Processing Record 18 of Set 1 | coquimbo
# Processing Record 19 of Set 1 | torres
# Processing Record 20 of Set 1 | codrington
# Processing Record 21 of Set 1 | fale old settlement
# Processing Record 22 of Set 1 | port mathurin
# Processing Record 23 of Set 1 | la ronge
# Processing Record 24 of Set 1 | papatowai
# Processing Record 25 of Set 1 | margaret river
# Processing Record 26 of Set 1 | saipan
# Processing Record 27 of Set 1 | hawaiian paradise park
# Processing Record 28 of Set 1 | freeport
# Processing Record 29 of Set 1 | bubaque
# Processing Record 30 of Set 1 | jamestown
# Processing Record 31 of Set 1 | avarua
# Processing Record 32 of Set 1 | albany
# Processing Record 33 of Set 1 | waitangi
# Processing Record 34 of Set 1 | puerto natales
# Processing Record 35 of Set 1 | brokopondo
# Processing Record 36 of Set 1 | tete
# Processing Record 37 of Set 1 | patnanungan
# Processing Record 38 of Set 1 | adamstown
# Processing Record 39 of Set 1 | anloga
# Processing Record 40 of Set 1 | abepura
# Processing Record 41 of Set 1 | alofi
# Processing Record 42 of Set 1 | edinburgh of the seven seas
# Processing Record 43 of Set 1 | fuglafjordur
# Processing Record 44 of Set 1 | touros
# Processing Record 45 of Set 1 | longyearbyen
# Processing Record 46 of Set 1 | arteche
# Processing Record 47 of Set 1 | itoman
# Processing Record 48 of Set 1 | belmonte
# Processing Record 49 of Set 1 | new norfolk
# Processing Record 50 of Set 1 
# Processing Record 47 of Set 3 | mount isa
# Processing Record 48 of Set 3 | maceio
# Processing Record 49 of Set 3 | port lincoln
# Processing Record 0 of Set 4 | pavlovka
# Processing Record 1 of Set 4 | plettenberg bay
# Processing Record 2 of Set 4 | malangali
# Processing Record 3 of Set 4 | chimbote
# Processing Record 4 of Set 4 | monrovia
# Processing Record 5 of Set 4 | utrik
# Processing Record 6 of Set 4 | inza
# Processing Record 7 of Set 4 | whitehorse
# Processing Record 8 of Set 4 | cole harbour
# Processing Record 9 of Set 4 | hamilton
# Processing Record 10 of Set 4 | kodiak
# Processing Record 11 of Set 4 | island harbour
# Processing Record 12 of Set 4 | labrador city
# Processing Record 13 of Set 4 | antsiranana
# Processing Record 14 of Set 4 | tokar
# Processing Record 15 of Set 4 | acapulco de juarez
# Processing Record 16 of Set 4 | haiku-pauwela
# Processing Record 17 of Set 4 | ornskoldsvik
# Processing Record 18 of Set 4 | ribeira grande
# Processing Record 19 of Set 4 | flin flon
# Processing Record 20 of Set 4 | porto velho
# Processing Record 21 of Set 4 | talnakh
# Processing Record 22 of Set 4 | georgetown
# Processing Record 23 of Set 4 | linjiang
# Processing Record 24 of Set 4 | lugoff
# Processing Record 25 of Set 4 | ubon ratchathani
# Processing Record 26 of Set 4 | lebu
# Processing Record 27 of Set 4 | road town
# Processing Record 28 of Set 4 | sambava
# Processing Record 29 of Set 4 | kota belud
# Processing Record 30 of Set 4 | sai buri
# Processing Record 31 of Set 4 | mersing
# Processing Record 32 of Set 4 | svislach
# Processing Record 33 of Set 4 | port saint john's
# Processing Record 34 of Set 4 | port glaud
# City not found. Skipping...
# Processing Record 35 of Set 4 | novyy urgal
# Processing Record 36 of Set 4 | talcahuano
# Processing Record 37 of Set 4 | beloyarskiy
# Processing Record 38 of Set 4 | cabedelo
# Processing Record 39 of Set 4 | qaqortoq
# Processing Record 40 of Set 4 | fort st. john
# Processing Record 41 of Set 4 | mejit
# Processing Record 42 of Set 4 | arish
# Processing Record 43 of Set 4 | geraldton
# Processing Record 44 of Set 4 | north platte
# Processing Record 45 of Set 4 | cambria
# Processing Record 46 of Set 4 | murmashi
# Processing Record 47 of Set 4 | altay
# Processing Record 48 of Set 4 | alaghsas
# Processing Record 49 of Set 4 | winejok
# City not found. Skipping...
# Processing Record 0 of Set 5 | punta arenas
# Processing Record 1 of Set 5 | lihue
# Processing Record 2 of Set 5 | al jawf
# Processing Record 3 of Set 5 | hastings
# Processing Record 4 of Set 5 | kapuskasing
# Processing Record 5 of Set 5 | kuyeda
# Processing Record 6 of Set 5 | hermanus
# Processing Record 7 of Set 5 | taligaman
# Processing Record 8 of Set 5 | sarandi del yi
# Processing Record 9 of Set 5 | vernon
# Processing Record 10 of Set 5 | khirdalan
# Processing Record 11 of Set 5 | altamira
# Processing Record 12 of Set 5 | vorgashor
# Processing Record 13 of Set 5 | belyy yar
# Processing Record 14 of Set 5 | huehuetenango
# Processing Record 15 of Set 5 | abbeville
# Processing Record 16 of Set 5 | san pedro pochutla
# Processing Record 17 of Set 5 | lekki
# City not found. Skipping...
# Processing Record 18 of Set 5 | machico
# Processing Record 19 of Set 5 | broken hill
# Processing Record 20 of Set 5 | visby
# Processing Record 21 of Set 5 | vilyuchinsk
# Processing Record 22 of Set 5 | zell am see
# Processing Record 23 of Set 5 | pionerskiy
# Processing Record 24 of Set 5 | zahedan
# Processing Record 25 of Set 5 | codajas
# Processing Record 26 of Set 5 | shingu
# Processing Record 27 of Set 5 | phongsali
# Processing Record 28 of Set 5 | paphos
# Processing Record 29 of Set 5 | port-vila
# Processing Record 30 of Set 5 | sao jose da coroa grande
# Processing Record 31 of Set 5 | keflavik
# Processing Record 32 of Set 5 | namsos
# Processing Record 33 of Set 5 | calvinia
# Processing Record 34 of Set 5 | east london
# Processing Record 35 of Set 5 | champerico
# Processing Record 36 of Set 5 | taoudenni
# Processing Record 37 of Set 5 | nizhnevartovsk
# Processing Record 38 of Set 5 | mzimba
# Processing Record 39 of Set 5 | rouissat
# Processing Record 40 of Set 5 | yarmouth
# Processing Record 41 of Set 5 | ibradi
# Processing Record 42 of Set 5 | okha
# Processing Record 43 of Set 5 | alotau
# City not found. Skipping...
# Processing Record 44 of Set 5 | kalispell
# Processing Record 45 of Set 5 | tarawa
# Processing Record 46 of Set 5 | anadyr
# Processing Record 47 of Set 5 | 'ohonua
# City not found. Skipping...
# Processing Record 48 of Set 5 | hadibu
# Processing Record 49 of Set 5 | afaahiti
# Processing Record 0 of Set 6 | kurmuk
# Processing Record 1 of Set 6 | harnosand
# Processing Record 2 of Set 6 | mazamari
# Processing Record 3 of Set 6 | troitsko-pechorsk
# Processing Record 4 of Set 6 | ormara
# Processing Record 5 of Set 6 | riobamba
# Processing Record 6 of Set 6 | senillosa
# Processing Record 7 of Set 6 | igrim
# Processing Record 8 of Set 6 | qamdo
# Processing Record 9 of Set 6 | malabar
# Processing Record 10 of Set 6 | colares
# Processing Record 11 of Set 6 | leava
# Processing Record 12 of Set 6 | newman
# Processing Record 13 of Set 6 | richards bay
# Processing Record 14 of Set 6 | ispir
# Processing Record 15 of Set 6 | ayvacik
# Processing Record 16 of Set 6 | praia da vitoria
# Processing Record 17 of Set 6 | mirny
# Processing Record 18 of Set 6 | laguna
# Processing Record 19 of Set 6 | pamandzi
# Processing Record 20 of Set 6 | baruun-urt
# Processing Record 21 of Set 6 | woolgoolga
# Processing Record 22 of Set 6 | salinas
# Processing Record 23 of Set 6 | yeniseysk
# Processing Record 24 of Set 6 | mount gambier
# Processing Record 25 of Set 6 | cockburn town
# Processing Record 26 of Set 6 | joshimath
# Processing Record 27 of Set 6 | constantia
# Processing Record 28 of Set 6 | bridgewater
# Processing Record 29 of Set 6 | kapa'a
# Processing Record 30 of Set 6 | kristiansund
# Processing Record 31 of Set 6 | thomaston
# Processing Record 32 of Set 6 | buchanan
# Processing Record 33 of Set 6 | porto novo
# Processing Record 34 of Set 6 | aoulef
# Processing Record 35 of Set 6 | gorontalo
# Processing Record 36 of Set 6 | inhambane
# Processing Record 37 of Set 6 | mossel bay
# Processing Record 38 of Set 6 | iquique
# Processing Record 39 of Set 6 | sao joao da barra
# Processing Record 40 of Set 6 | sertanopolis
# Processing Record 41 of Set 6 | taytay
# Processing Record 42 of Set 6 | ust'-kalmanka
# Processing Record 43 of Set 6 | san agustin de valle fertil
# Processing Record 44 of Set 6 | masterton
# Processing Record 45 of Set 6 | mogadishu
# Processing Record 46 of Set 6 | cudillero
# Processing Record 47 of Set 6 | uturoa
# Processing Record 48 of Set 6 | antofagasta
# Processing Record 49 of Set 6 | juegang
# Processing Record 0 of Set 7 | ola
# Processing Record 1 of Set 7 | vadso
# Processing Record 2 of Set 7 | sofifi
# City not found. Skipping...
# Processing Record 3 of Set 7 | inirida
# Processing Record 4 of Set 7 | west odessa
# Processing Record 5 of Set 7 | mytilene
# Processing Record 6 of Set 7 | at-bashi
# Processing Record 7 of Set 7 | mukah
# City not found. Skipping...
# Processing Record 8 of Set 7 | vandalia
# Processing Record 9 of Set 7 | yanchep
# Processing Record 10 of Set 7 | victorica
# Processing Record 11 of Set 7 | lucapa
# Processing Record 12 of Set 7 | moussoro
# Processing Record 13 of Set 7 | shiqian
# Processing Record 14 of Set 7 | vorkuta
# Processing Record 15 of Set 7 | trondheim
# Processing Record 16 of Set 7 | pointe michel
# Processing Record 17 of Set 7 | villa ojo de agua
# Processing Record 18 of Set 7 | pierre
# Processing Record 19 of Set 7 | rabo de peixe
# Processing Record 20 of Set 7 | hayma'
# City not found. Skipping...
# Processing Record 21 of Set 7 | necochea
# Processing Record 22 of Set 7 | lewistown
# Processing Record 23 of Set 7 | douglas
# Processing Record 24 of Set 7 | bac lieu
# Processing Record 25 of Set 7 | labatlan
# Processing Record 26 of Set 7 | seven pagodas
# Processing Record 27 of Set 7 | caconda
# Processing Record 28 of Set 7 | kayangel
# Processing Record 29 of Set 7 | san carlos de bariloche
# Processing Record 30 of Set 7 | kolobrzeg
# Processing Record 31 of Set 7 | abbotsford
# Processing Record 32 of Set 7 | dudinka
# Processing Record 33 of Set 7 | inderbor
# Processing Record 34 of Set 7 | caromatan
# Processing Record 35 of Set 7 | bargara
# City not found. Skipping...
# Processing Record 36 of Set 7 | prince rupert
# Processing Record 37 of Set 7 | puerto baquerizo moreno
# Processing Record 38 of Set 7 | polyarnyy
# Processing Record 39 of Set 7 | qarauyl
# Processing Record 40 of Set 7 | shalqar
# Processing Record 41 of Set 7 | paredon
# Processing Record 42 of Set 7 | rocha
# Processing Record 43 of Set 7 | afsin
# Processing Record 44 of Set 7 | remire-montjoly
# Processing Record 45 of Set 7 | magadan
# Processing Record 46 of Set 7 | gifford
# Processing Record 47 of Set 7 | fortuna
# Processing Record 48 of Set 7 | iskateley
# Processing Record 49 of Set 7 | huntingdon
# Processing Record 0 of Set 8 | kudymkar
# Processing Record 1 of Set 8 | aykhal
# Processing Record 2 of Set 8 | iwanai
# Processing Record 3 of Set 8 | arraial do cabo
# Processing Record 4 of Set 8 | hansot
# Processing Record 5 of Set 8 | ginir
# Processing Record 6 of Set 8 | manta
# Processing Record 7 of Set 8 | belen
# Processing Record 8 of Set 8 | trinidad
# Processing Record 9 of Set 8 | pibor
# City not found. Skipping...
# Processing Record 10 of Set 8 | marka
# Processing Record 11 of Set 8 | san cristobal
# Processing Record 12 of Set 8 | dubbo
# Processing Record 13 of Set 8 | sungailiat
# Processing Record 14 of Set 8 | teknaf
# Processing Record 15 of Set 8 | guerrero negro
# Processing Record 38 of Set 9 | melekeok village
# Processing Record 39 of Set 9 | ternate
# Processing Record 40 of Set 9 | sheridan
# Processing Record 41 of Set 9 | murudeshwara
# Processing Record 42 of Set 9 | rio grande
# Processing Record 43 of Set 9 | maranding
# Processing Record 44 of Set 9 | soto la marina
# Processing Record 45 of Set 9 | kencong
# Processing Record 46 of Set 9 | corowa
# Processing Record 47 of Set 9 | espargos
# City not found. Skipping...
# Processing Record 48 of Set 9 | wyrzysk
# Processing Record 49 of Set 9 | pimenta bueno
# Processing Record 0 of Set 10 | karakol
# Processing Record 1 of Set 10 | jinka
# Processing Record 2 of Set 10 | toliara
# Processing Record 3 of Set 10 | cayambe
# Processing Record 4 of Set 10 | bee cave
# Processing Record 5 of Set 10 | asau village
# City not found. Skipping...
# Processing Record 6 of Set 10 | santana
# Processing Record 7 of Set 10 | mercedes
# Processing Record 8 of Set 10 | as saffaniyah
# Processing Record 9 of Set 10 | angelholm
# City not found. Skipping...
# Processing Record 10 of Set 10 | santa terezinha
# Processing Record 11 of Set 10 | kasongo-lunda
# Processing Record 12 of Set 10 | thinadhoo
# Processing Record 13 of Set 10 | el granada
# Processing Record 14 of Set 10 | zuwarah
# Processing Record 15 of Set 10 | yankton
# Processing Record 16 of Set 10 | thunder bay
# Processing Record 17 of Set 10 | filipstad
# Processing Record 18 of Set 10 | begamganj
# Processing Record 19 of Set 10 | kirensk
# Processing Record 20 of Set 10 | chibougamau
# Processing Record 21 of Set 10 | cargados carajos
# City not found. Skipping...
# Processing Record 22 of Set 10 | gaspe
# Processing Record 23 of Set 10 | colonia
# Processing Record 24 of Set 10 | protaras
# Processing Record 25 of Set 10 | san luis de la loma
# Processing Record 26 of Set 10 | yuzhno-kurilsk
# Processing Record 27 of Set 10 | santa cruz
# Processing Record 28 of Set 10 | odienne
# Processing Record 29 of Set 10 | kimbe
# Processing Record 30 of Set 10 | vingt cinq
# City not found. Skipping...
# Processing Record 31 of Set 10 | queenstown
# Processing Record 32 of Set 10 | page
# Processing Record 33 of Set 10 | coahuayana de hidalgo
# Processing Record 34 of Set 10 | ofunato
# Processing Record 35 of Set 10 | kasangulu
# Processing Record 36 of Set 10 | kismayo
# Processing Record 37 of Set 10 | baukau
# Processing Record 38 of Set 10 | aral
# Processing Record 39 of Set 10 | howrah
# Processing Record 40 of Set 10 | constitucion
# Processing Record 41 of Set 10 | pandan
# Processing Record 42 of Set 10 | roxborough park
# Processing Record 43 of Set 10 | el daein
# City not found. Skipping...
# Processing Record 44 of Set 10 | labytnangi
# Processing Record 45 of Set 10 | jiuquan
# Processing Record 46 of Set 10 | floro
# Processing Record 47 of Set 10 | deqing
# Processing Record 48 of Set 10 | vila franca do campo
# Processing Record 49 of Set 10 | ruteng
# Processing Record 0 of Set 11 | armidale
# Processing Record 1 of Set 11 | chernyshevskiy
# Processing Record 2 of Set 11 | quellon
# Processing Record 3 of Set 11 | tarauaca
# Processing Record 4 of Set 11 | mukalla
# Processing Record 5 of Set 11 | palikir - national government center
# Processing Record 6 of Set 11 | gadzhiyevo
# Processing Record 7 of Set 11 | luwuk
# Processing Record 8 of Set 11 | bel ombre
# Processing Record 9 of Set 11 | astara
# Processing Record 10 of Set 11 | chui
# Processing Record 11 of Set 11 | verkhnevilyuysk
# Processing Record 12 of Set 11 | alice springs
# Processing Record 13 of Set 11 | sola
# Processing Record 14 of Set 11 | smithers
# Processing Record 15 of Set 11 | fukuecho
# Processing Record 16 of Set 11 | pirallahi
# Processing Record 17 of Set 11 | mkushi
# Processing Record 18 of Set 11 | dompu
# Processing Record 19 of Set 11 | poronaysk
# Processing Record 20 of Set 11 | nuuk
# Processing Record 21 of Set 11 | karratha
# Processing Record 22 of Set 11 | kuldiga
# Processing Record 23 of Set 11 | pingliang
# Processing Record 24 of Set 11 | tawau
# Processing Record 25 of Set 11 | lusambo
# Processing Record 26 of Set 11 | hefei
# Processing Record 27 of Set 11 | sonsorol village
# City not found. Skipping...
# Processing Record 28 of Set 11 | fuvahmulah
# City not found. Skipping...
# Processing Record 29 of Set 11 | otradnaya
# Processing Record 30 of Set 11 | fisterra
# Processing Record 31 of Set 11 | alo
# Processing Record 32 of Set 11 | plast
# Processing Record 33 of Set 11 | pak phanang
# Processing Record 34 of Set 11 | kokpekty
# Processing Record 35 of Set 11 | padang
# Processing Record 36 of Set 11 | volodarskiy
# Processing Record 37 of Set 11 | tsiombe
# Processing Record 38 of Set 11 | tianpeng
# Processing Record 39 of Set 11 | tonj
# Processing Record 40 of Set 11 | copala
# Processing Record 41 of Set 11 | keelung
# Processing Record 42 of Set 11 | zaragoza
# Processing Record 43 of Set 11 | tamandare
# Processing Record 44 of Set 11 | bathsheba
# Processing Record 45 of Set 11 | nioki
# Processing Record 46 of Set 11 | naze
# Processing Record 47 of Set 11 | hasaki
# Processing Record 48 of Set 11 | namtsy
# Processing Record 49 of Set 11 | cestos city
# Processing Record 0 of Set 12 | amga
# Processing Record 1 of Set 12 | am timan
# Processing Record 2 of Set 12 | puerto leguizamo
# Processing Record 3 of Set 12 | sinjai
# Processing Record 4 of Set 12 | cruzeiro do sul
# Processing Record 5 of Set 12 | auterive
# Processing Record 6 of Set 12 | am djarass
# City not found. Skipping...
# Processing Record 7 of Set 12 | stawell
# Processing Record 8 of Set 12 | aasiaat
# Processing Record 9 of Set 12 | hammerfest
# Processing Record 10 of Set 12 | balqash
# Processing Record 11 of Set 12 | nueva gerona
# Processing Record 12 of Set 12 | huittinen
# Processing Record 13 of Set 12 | kintinku
# Processing Record 14 of Set 12 | coruripe
# Processing Record 15 of Set 12 | ortaca
# Processing Record 16 of Set 12 | merritt
# Processing Record 17 of Set 12 | zheleznodorozhnyy
# Processing Record 18 of Set 12 | shagonar
# Processing Record 19 of Set 12 | mutuali
# Processing Record 20 of Set 12 | hasparren
# Processing Record 21 of Set 12 | vilhena
# Processing Record 22 of Set 12 | quepos
# Processing Record 23 of Set 12 | walvis bay
# Processing Record 24 of Set 12 | kingston
# Processing Record 25 of Set 12 | garissa
# Processing Record 26 of Set 12 | la passe
# Processing Record 27 of Set 12 | camargo
# Processing Record 28 of Set 12 | yaiza
# Processing Record 29 of Set 12 | arcot
# Processing Record 30 of Set 12 | eyl
# Processing Record 31 of Set 12 | terrace
# Processing Record 32 of Set 12 | chonchi
# Processing Record 33 of Set 12 | chaiya
# Processing Record 34 of Set 12 | hoxtolgay
# City not found. Skipping...
# Processing Record 35 of Set 12 | yirol
# City not found. Skipping...
# Processing Record 36 of Set 12 | lubao
# Processing Record 37 of Set 12 | emerald
# Processing Record 38 of Set 12 | fada
# Processing Record 39 of Set 12 | kolonia town
# Processing Record 40 of Set 12 | santa vitoria do palmar
# Processing Record 41 of Set 12 | inarajan village
# Processing Record 42 of Set 12 | ma'rib
# Processing Record 43 of Set 12 | mae tha
# Processing Record 44 of Set 12 | mumford
# Processing Record 45 of Set 12 | cannonvale
# Processing Record 46 of Set 12 | jertih
# Processing Record 47 of Set 12 | shohimardon
# Processing Record 48 of Set 12 | mayen abun
# City not found. Skipping...
# Processing Record 49 of Set 12 | shimoda
# Processing Record 0 of Set 13 | wuwei
# Processing Record 1 of Set 13 | enoch
# Processing Record 2 of Set 13 | kiunga
# Processing Record 3 of Set 13 | radom
# Processing Record 4 of Set 13 | chilliwack
# Processing Record 5 of Set 13 | moissala
# Processing Record 6 of Set 13 | tasbuget
# City not found. Skipping...
# Processing Record 7 of Set 13 | karosta
# City not found. Skipping...
# Processing Record 8 of Set 13 | marakkanam
# Processing Record 9 of Set 13 | manokwari
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          580
# Lat           580
# Lng           580
# Max Temp      580
# Humidity      580
# Cloudiness    580
# Wind Speed    580
# Country       580
# Date          580
# dtype: int64

# %%
# Display sample data
print(city_data_df)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         nagqu  31.5000   92.0000       -10        59           2
# 1       college  64.8569 -147.8028       -28        73          40
# 2        mizdah  31.4451   12.9801        11        86           4
# 3      ust-nera  64.5667  143.2000       -22        96         100
# 4      bilibino  68.0546  166.4372       -26        87           3
# ..          ...      ...       ...       ...       ...         ...
# 575       radom  51.4025   21.1471         2        93         100
# 576  chilliwack  49.1747 -121.9443         6        94          97
# 577    moissala   8.3404   17.7663        20        30           8
# 578  marakkanam  12.2000   79.9500        26        81         100
# 579   manokwari  -0.8667  134.0833        29        70          90
#
#      Wind Speed Country        Date
# 0          2.31      CN  1702608013
# 1          0.00      US  1702607891
# 2          3.57      LY  1702608273
# 3          3.38      RU  1702608072
# 4          3.57      RU  1702607897
# ..          ...     ...         ...
# 575        2.24      PL  1702608686
# 576        3.60      CA  1702608687
# 577        1.59      TD  1702608688
# 578        7.57      IN  1702608690
# 579        3.92      ID  1702608691
#
# [580 rows x 9 columns]

# %%
# Export the City_Data into a csv
city_data_df.to_csv("cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0           nagqu  31.5000   92.0000       -10        59           2
# 1         college  64.8569 -147.8028       -28        73          40
# 2          mizdah  31.4451   12.9801        11        86           4
# 3        ust-nera  64.5667  143.2000       -22        96         100
# 4        bilibino  68.0546  166.4372       -26        87           3
#
#          Wind Speed Country        Date
# City_ID
# 0              2.31      CN  1702608013
# 1              0.00      US  1702607891
# 2              3.57      LY  1702608273
# 3              3.38      RU  1702608072
# 4              3.57      RU  1702607897

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
plot_data=pd.DataFrame(city_data_df)
#city_data_df.head()

# %%
# Build scatter plot for latitude vs. temperature

#plot_data=pd.DataFrame(city_data_df)
weatherx=plot_data['Lat']
weathery=plot_data['Max Temp']

#Incorporate the other graph properties

fig1,ax1=plt.subplots(figsize=(10,8))
plt.scatter(x=weatherx,y=weathery,s=10,c='blue')
plt.title('City Max Latitude vs. Temperature (December 2023)')
plt.xlabel('Max Temperature (C)')
plt.ylabel('Latitude')

# Save the figure
plt.savefig("Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
latx=plot_data['Lat']
laty=plot_data['Humidity']

# Incorporate the other graph properties

fig1,ax1=plt.subplots(figsize=(10,8))
plt.scatter(x=latx,y=laty,s=10,c='red')
plt.title('City Latitude vs. Humidity (December 2023)')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')

# Save the figure
plt.savefig("Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
cloudx=plot_data['Lat']
cloudy=plot_data['Cloudiness']

# Incorporate the other graph properties

fig1,ax1=plt.subplots(figsize=(10,8))
plt.scatter(x=cloudx,y=cloudy,s=15,c='green')
plt.title('City Latitude vs. Cloudiness (December 2023)')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')

# Save the figure
plt.savefig("Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
windspeedx=plot_data['Lat']
windspeedy=plot_data['Wind Speed']

# Incorporate the other graph properties

fig1,ax1=plt.subplots(figsize=(10,8))
plt.scatter(x=windspeedx,y=windspeedy,s=15,c='DarkBlue')
plt.title('City Latitude vs. Wind Speed (December 2023)')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')

# Save the figure
plt.savefig("Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
#model=linregress(x,y)

# %%
# Define a function to create Linear Regression plots

#Testing values
#xvalues=plot_data['Lat']
#yvalues=plot_data['Max Temp']
#model=st.lingress(x,y)
def linear_regression (xvalues, yvalues, xlabel,ylabel,hemisphere,textcoordinates,ylim=None):
        (slope,intercept,rvalue,pvalue,stderr)=linregress(xvalues,yvalues)
    
        slopeline=xvalues*slope+intercept

        linear_eq= 'Y = ' + str(round(slope,2)) + 'X +' + str(round(intercept,2))

        fig1,ax1=plt.subplots(figsize=(10,8))
        plt.scatter(x=xvalues,y=yvalues,s=15,color='DarkBlue')
        #plt.scatter(x=xvalues,y=yvalues,s=15,color='black')
        plt.plot(xvalues,slopeline,color='Red')
        plt.xlabel(xlabel)
        plt.ylabel(ylabel)
        if ylim is not None:
            plt.ylim(0,ylim)
            plt.annotate(linear_eq, textcoordinates,fontsize=15,color='red')

        print(f'The r-squared is: {rvalue**2}')
        #correlation=st.pearsonr(xvalues,yvalues)
        #print(f'The correlation between both values is {round(correlation[0],2)}')

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_df=plot_data.loc[plot_data['Lat'] >= 0]
northern_hemi_df=pd.DataFrame(northern_df)
# Display sample data
northern_hemi_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0           nagqu  31.5000   92.0000       -10        59           2
# 1         college  64.8569 -147.8028       -28        73          40
# 2          mizdah  31.4451   12.9801        11        86           4
# 3        ust-nera  64.5667  143.2000       -22        96         100
# 4        bilibino  68.0546  166.4372       -26        87           3
#
#          Wind Speed Country        Date
# City_ID
# 0              2.31      CN  1702608013
# 1              0.00      US  1702607891
# 2              3.57      LY  1702608273
# 3              3.38      RU  1702608072
# 4              3.57      RU  1702607897

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_df=plot_data[plot_data['Lat'] <=0]
southern_hemi_df=pd.DataFrame(southern_df)

# Display sample data
southern_hemi_df.head()
# Out:
#                         City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 6        san antonio de pale  -1.4014    5.6325        27        82
# 8                  grytviken -54.2811  -36.5092         3        73
# 10             blackmans bay -43.0167  147.3167        19        49
# 11                 kilindoni  -7.9139   39.6668        28        77
# 13         port-aux-francais -49.3500   70.2167         6        86
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 6                15        2.93      GQ  1702608210
# 8                 2        1.89      GS  1702607811
# 10              100        0.89      AU  1702607838
# 11               59        3.66      TZ  1702608246
# 13               77       11.62      TF  1702607807

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x=northern_hemi_df['Lat']
y=northern_hemi_df['Max Temp']

linear_regression(x,y,'Latitude','Max Temp','Northern',(15,15))

plt.show()
# Out:
# The r-squared is: 0.7269105400151827

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
